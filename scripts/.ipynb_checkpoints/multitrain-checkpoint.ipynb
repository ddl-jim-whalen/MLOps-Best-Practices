# %%
# this code is generated by the Domino Code Assist toolbar button
import domino_code_assist as dca
dca.init()
# Out:
# Cannot show ipywidgets in text

# %%
import domino
import os
import time

print('Initializing Domino Project for API calls')

#initialize Domino Project
domino_project =domino.Domino(project = str(os.environ.get('DOMINO_PROJECT_OWNER')+'/'+os.environ.get('DOMINO_PROJECT_NAME')),
                              api_key = os.environ.get('DOMINO_USER_API_KEY'),
                              domino_token_file=os.environ.get('DOMINO_TOKEN_FILE'))
# Out:
# Initializing Domino Project for API calls

# %%
print('Kicking off sklearn model training')
domino_project.job_start(command='scripts/sklearn_model_train.py')
# Out:
# Kicking off sklearn model training
# {'number': 23,
#  'id': '653aa49076fe3a388e72af17',
#  'queuedJobHistoryDetails': {'expectedWait': '',
#   'explanation': 'Your run has been put in a queue for processing.',
#   'helpText': "In a few seconds, Domino will start the process of assigning your run to a machine. If the status doesn't change within a minute, please contact your admin team."},
#  'stageTime': {'submissionTime': 1698342032465},
#  'tags': [],
#  'jobRunCommand': "'scripts/sklearn_model_train.py'",
#  'usage': None,
#  'startedBy': {'id': '64de666663a5d44f77a59f6b', 'username': 'jim_whalen'},
#  'commentsCount': 0,
#  'title': None,
#  'commitDetails': {'inputCommitId': '1fce1b7cdbc67aaad6cf31a9a535b53c03b78914'},
#  'dominoStats': [],
#  'statuses': {'isCompleted': False,
#   'isArchived': False,
#   'isScheduled': False,
#   'volumeRecoverabilityStatus': 'NoActionNecessary',
#   'executionStatus': 'Queued'},
#  'mainRepoGitRef': {'type': 'head'},
#  'dependentRepositories': [{'id': '65396f3276fe3a388e72ae1a',
#    'name': 'MLOps-Best-Practices',
#    'uri': 'https://github.com/ddl-jim-whalen/MLOps-Best-Practices.git',
#    'ref': '(Default branch)',
#    'serviceProvider': 'github'}],
#  'dependentDatasetMounts': [{'datasetId': '65396f3276fe3a388e72ae1d',
#    'snapshotId': '65396f3276fe3a388e72ae1c',
#    'snapshotVersion': 0,
#    'datasetName': 'WineQuality-Git',
#    'projectId': '65396f3076fe3a388e72ae19',
#    'isInput': False,
#    'containerPath': '/mnt/data/WineQuality-Git'},
#   {'datasetId': '653a640ec89cb93b0f7a8aae',
#    'snapshotId': '653a640ec89cb93b0f7a8aad',
#    'snapshotVersion': 0,
#    'datasetName': 'prediction_data',
#    'projectId': '65396f3076fe3a388e72ae19',
#    'isInput': False,
#    'containerPath': '/mnt/data/prediction_data'}],
#  'dependentProjects': [],
#  'suggestDatasets': False,
#  'goalIds': [],
#  'runLauncherId': None,
#  'dependentExternalVolumeMounts': [],
#  'computeCluster': None,
#  'dataPlane': {'id': '000000000000000000000000',
#   'name': 'Local',
#   'namespace': 'domino-compute',
#   'isLocal': True,
#   'configuration': {},
#   'status': {'state': 'Healthy',
#    'message': '',
#    'version': '1.1.3',
#    'lastHeartbeatTimestamp': 1698341984782},
#   'isHealthy': True,
#   'isArchived': False,
#   'isFileSyncDisabled': False},
#  'snapshotDatasetsOnCompletion': False}

# %%
print('Kicking off R model training')
domino_project.job_start(command='scripts/R_model_train.R')
# Out:
# Kicking off R model training
# {'number': 24,
#  'id': '653aa4a176fe3a388e72af1c',
#  'queuedJobHistoryDetails': {'expectedWait': '',
#   'explanation': 'Your run has been put in a queue for processing.',
#   'helpText': "In a few seconds, Domino will start the process of assigning your run to a machine. If the status doesn't change within a minute, please contact your admin team."},
#  'stageTime': {'submissionTime': 1698342049238},
#  'tags': [],
#  'jobRunCommand': "'scripts/R_model_train.R'",
#  'usage': None,
#  'startedBy': {'id': '64de666663a5d44f77a59f6b', 'username': 'jim_whalen'},
#  'commentsCount': 0,
#  'title': None,
#  'commitDetails': {'inputCommitId': '1fce1b7cdbc67aaad6cf31a9a535b53c03b78914'},
#  'dominoStats': [],
#  'statuses': {'isCompleted': False,
#   'isArchived': False,
#   'isScheduled': False,
#   'volumeRecoverabilityStatus': 'NoActionNecessary',
#   'executionStatus': 'Queued'},
#  'mainRepoGitRef': {'type': 'head'},
#  'dependentRepositories': [{'id': '65396f3276fe3a388e72ae1a',
#    'name': 'MLOps-Best-Practices',
#    'uri': 'https://github.com/ddl-jim-whalen/MLOps-Best-Practices.git',
#    'ref': '(Default branch)',
#    'serviceProvider': 'github'}],
#  'dependentDatasetMounts': [{'datasetId': '65396f3276fe3a388e72ae1d',
#    'snapshotId': '65396f3276fe3a388e72ae1c',
#    'snapshotVersion': 0,
#    'datasetName': 'WineQuality-Git',
#    'projectId': '65396f3076fe3a388e72ae19',
#    'isInput': False,
#    'containerPath': '/mnt/data/WineQuality-Git'},
#   {'datasetId': '653a640ec89cb93b0f7a8aae',
#    'snapshotId': '653a640ec89cb93b0f7a8aad',
#    'snapshotVersion': 0,
#    'datasetName': 'prediction_data',
#    'projectId': '65396f3076fe3a388e72ae19',
#    'isInput': False,
#    'containerPath': '/mnt/data/prediction_data'}],
#  'dependentProjects': [],
#  'suggestDatasets': False,
#  'goalIds': [],
#  'runLauncherId': None,
#  'dependentExternalVolumeMounts': [],
#  'computeCluster': None,
#  'dataPlane': {'id': '000000000000000000000000',
#   'name': 'Local',
#   'namespace': 'domino-compute',
#   'isLocal': True,
#   'configuration': {},
#   'status': {'state': 'Healthy',
#    'message': '',
#    'version': '1.1.3',
#    'lastHeartbeatTimestamp': 1698342044777},
#   'isHealthy': True,
#   'isArchived': False,
#   'isFileSyncDisabled': False},
#  'snapshotDatasetsOnCompletion': False}

# %%
print('Kicking off h2o model training')
domino_project.job_start(command='scripts/h2o_model_train.py')
# Out:
# Kicking off h2o model training
# {'number': 25,
#  'id': '653aa4b276fe3a388e72af21',
#  'queuedJobHistoryDetails': {'expectedWait': '',
#   'explanation': 'Your run has been put in a queue for processing.',
#   'helpText': "In a few seconds, Domino will start the process of assigning your run to a machine. If the status doesn't change within a minute, please contact your admin team."},
#  'stageTime': {'submissionTime': 1698342066683},
#  'tags': [],
#  'jobRunCommand': "'scripts/h2o_model_train.py'",
#  'usage': None,
#  'startedBy': {'id': '64de666663a5d44f77a59f6b', 'username': 'jim_whalen'},
#  'commentsCount': 0,
#  'title': None,
#  'commitDetails': {'inputCommitId': '1fce1b7cdbc67aaad6cf31a9a535b53c03b78914'},
#  'dominoStats': [],
#  'statuses': {'isCompleted': False,
#   'isArchived': False,
#   'isScheduled': False,
#   'volumeRecoverabilityStatus': 'NoActionNecessary',
#   'executionStatus': 'Queued'},
#  'mainRepoGitRef': {'type': 'head'},
#  'dependentRepositories': [{'id': '65396f3276fe3a388e72ae1a',
#    'name': 'MLOps-Best-Practices',
#    'uri': 'https://github.com/ddl-jim-whalen/MLOps-Best-Practices.git',
#    'ref': '(Default branch)',
#    'serviceProvider': 'github'}],
#  'dependentDatasetMounts': [{'datasetId': '65396f3276fe3a388e72ae1d',
#    'snapshotId': '65396f3276fe3a388e72ae1c',
#    'snapshotVersion': 0,
#    'datasetName': 'WineQuality-Git',
#    'projectId': '65396f3076fe3a388e72ae19',
#    'isInput': False,
#    'containerPath': '/mnt/data/WineQuality-Git'},
#   {'datasetId': '653a640ec89cb93b0f7a8aae',
#    'snapshotId': '653a640ec89cb93b0f7a8aad',
#    'snapshotVersion': 0,
#    'datasetName': 'prediction_data',
#    'projectId': '65396f3076fe3a388e72ae19',
#    'isInput': False,
#    'containerPath': '/mnt/data/prediction_data'}],
#  'dependentProjects': [],
#  'suggestDatasets': False,
#  'goalIds': [],
#  'runLauncherId': None,
#  'dependentExternalVolumeMounts': [],
#  'computeCluster': None,
#  'dataPlane': {'id': '000000000000000000000000',
#   'name': 'Local',
#   'namespace': 'domino-compute',
#   'isLocal': True,
#   'configuration': {},
#   'status': {'state': 'Healthy',
#    'message': '',
#    'version': '1.1.3',
#    'lastHeartbeatTimestamp': 1698342044777},
#   'isHealthy': True,
#   'isArchived': False,
#   'isFileSyncDisabled': False},
#  'snapshotDatasetsOnCompletion': False}
